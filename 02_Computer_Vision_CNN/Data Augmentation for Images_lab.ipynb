# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
img = load_img('path/to/image.jpg')  # Replace with your image path
img_array = img_to_array(img)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 from tensorflow.keras.preprocessing.image import load_img, img_to_array
# ----> 2 img = load_img('path/to/image.jpg')  # Replace with your image path
#       3 img_array = img_to_array(img)
#
# File ~\PycharmProjects\pythonProject3\.venv\Lib\site-packages\keras\src\utils\image_utils.py:235, in load_img(path, color_mode, target_size, interpolation, keep_aspect_ratio)
#     233     if isinstance(path, pathlib.Path):
#     234         path = str(path.resolve())
# --> 235     with open(path, "rb") as f:
#     236         img = pil_image.open(io.BytesIO(f.read()))
#     237 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'path/to/image.jpg'

# %%
datagen = ImageDataGenerator(rotation_range=40)

# %%
datagen = ImageDataGenerator(horizontal_flip=True, vertical_flip=True)

# %%
datagen = ImageDataGenerator(width_shift_range=0.2, height_shift_range=0.2)

# %%
aug_iter = datagen.flow(np.expand_dims(img_array, 0))
augmented_images = [next(aug_iter)[0].astype(np.uint8) for i in range(5)]

# Plot original and augmented images
fig, axes = plt.subplots(1, 6, figsize=(20, 20))
axes[0].imshow(img_array.astype(np.uint8))
axes[0].set_title("Original Image")
for i, aug_img in enumerate(augmented_images):
    axes[i+1].imshow(aug_img)
    axes[i+1].set_title(f"Augmented {i+1}")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 aug_iter = datagen.flow(np.expand_dims(img_array, 0))
#       2 augmented_images = [next(aug_iter)[0].astype(np.uint8) for i in range(5)]
#       4 # Plot original and augmented images
#
# NameError: name 'img_array' is not defined

# %%
datagen = ImageDataGenerator(
    rotation_range=40,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

# %%
train_data_gen = datagen.flow_from_directory(
    'path/to/training/data',
    target_size=(150, 150),
    batch_size=32,
    class_mode='binary'
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 train_data_gen = datagen.flow_from_directory(
#       2     'path/to/training/data',
#       3     target_size=(150, 150),
#       4     batch_size=32,
#       5     class_mode='binary'
#       6 )
#
# File ~\PycharmProjects\pythonProject3\.venv\Lib\site-packages\keras\src\legacy\preprocessing\image.py:1136, in ImageDataGenerator.flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1118 def flow_from_directory(
#    1119     self,
#    1120     directory,
#    (...)   1134     keep_aspect_ratio=False,
#    1135 ):
# -> 1136     return DirectoryIterator(
#    1137         directory,
#    1138         self,
#    1139         target_size=target_size,
# ...

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(1, activation='sigmoid')
])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# C:\Users\User\PycharmProjects\pythonProject3\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.fit(train_data_no_aug, epochs=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 model.fit(train_data_no_aug, epochs=10)
#
# NameError: name 'train_data_no_aug' is not defined

# %%
loss, accuracy = model.evaluate(test_data_no_aug)
print(f"Test accuracy without augmentation: {accuracy}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 loss, accuracy = model.evaluate(test_data_no_aug)
#       2 print(f"Test accuracy without augmentation: {accuracy}")
#
# NameError: name 'test_data_no_aug' is not defined

# %%
model.fit(train_data_gen, epochs=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 model.fit(train_data_gen, epochs=10)
#
# NameError: name 'train_data_gen' is not defined

# %%
loss_aug, accuracy_aug = model.evaluate(test_data_no_aug)
print(f"Test accuracy with augmentation: {accuracy_aug}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 loss_aug, accuracy_aug = model.evaluate(test_data_no_aug)
#       2 print(f"Test accuracy with augmentation: {accuracy_aug}")
#
# NameError: name 'test_data_no_aug' is not defined
