# %%
import tensorflow as tf

# Load data
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the data to a range of 0 to 1
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(10, activation='softmax')
])
# Out:
# C:\Users\User\PycharmProjects\pythonProject3\.venv\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model with batch normalization
batch_norm_history = model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9242 - loss: 0.2531 - val_accuracy: 0.9560 - val_loss: 0.1459
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 979us/step - accuracy: 0.9621 - loss: 0.1233 - val_accuracy: 0.9646 - val_loss: 0.1103
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 978us/step - accuracy: 0.9708 - loss: 0.0946 - val_accuracy: 0.9693 - val_loss: 0.0988
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 968us/step - accuracy: 0.9749 - loss: 0.0793 - val_accuracy: 0.9748 - val_loss: 0.0871
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 982us/step - accuracy: 0.9784 - loss: 0.0670 - val_accuracy: 0.9780 - val_loss: 0.0725
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 980us/step - accuracy: 0.9812 - loss: 0.0581 - val_accuracy: 0.9748 - val_loss: 0.0857
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 972us/step - accuracy: 0.9834 - loss: 0.0512 - val_accuracy: 0.9786 - val_loss: 0.0772
# Epoch 8/10
# ...

# %%
# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'\nTest accuracy with Batch Normalization: {test_acc:.2f}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step - accuracy: 0.9775 - loss: 0.0817
#
# Test accuracy with Batch Normalization: 0.98

# %%
model_without_bn = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model_without_bn.compile(optimizer='adam',
                         loss='sparse_categorical_crossentropy',
                         metrics=['accuracy'])

# Train the model without batch normalization
no_batch_norm_history = model_without_bn.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))

# Evaluate the model without batch normalization
test_loss_no_bn, test_acc_no_bn = model_without_bn.evaluate(x_test, y_test)
print(f'\nTest accuracy without Batch Normalization: {test_acc_no_bn:.2f}')
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 945us/step - accuracy: 0.9307 - loss: 0.2391 - val_accuracy: 0.9639 - val_loss: 0.1200
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 950us/step - accuracy: 0.9687 - loss: 0.1022 - val_accuracy: 0.9703 - val_loss: 0.0950
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9780 - loss: 0.0710 - val_accuracy: 0.9720 - val_loss: 0.0906
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9826 - loss: 0.0542 - val_accuracy: 0.9750 - val_loss: 0.0796
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9866 - loss: 0.0427 - val_accuracy: 0.9785 - val_loss: 0.0800
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9880 - loss: 0.0370 - val_accuracy: 0.9784 - val_loss: 0.0728
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9910 - loss: 0.0281 - val_accuracy: 0.9747 - val_loss: 0.0910
# Epoch 8/10
# ...
