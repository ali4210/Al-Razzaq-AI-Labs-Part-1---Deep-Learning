# %%
import numpy as np

# Define the hyperparameter grid
learning_rates = [0.001, 0.01, 0.1]
batch_sizes = [16, 32, 64]

# Create a list of all possible combinations
parameter_grid = [(lr, bs) for lr in learning_rates for bs in batch_sizes]

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist

def train_model(learning_rate, batch_size):
    # Load dataset
    (x_train, y_train), (x_test, y_test) = mnist.load_data()
    x_train, x_test = x_train / 255.0, x_test / 255.0

    # Model definition
    model = tf.keras.models.Sequential([
        tf.keras.layers.Flatten(input_shape=(28, 28)),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])

    # Compile the model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    # Train the model
    model.fit(x_train, y_train, epochs=5, batch_size=batch_size, validation_split=0.1)

    return model.evaluate(x_test, y_test, verbose=0)

# %%
results = []
for learning_rate, batch_size in parameter_grid:
    accuracy, loss = train_model(learning_rate, batch_size)
    results.append((learning_rate, batch_size, accuracy))
# Out:
# Epoch 1/5
# C:\Users\User\PycharmProjects\pythonProject3\.venv\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 3s 767us/step - accuracy: 0.9306 - loss: 0.2416 - val_accuracy: 0.9627 - val_loss: 0.1271
# Epoch 2/5
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 2s 722us/step - accuracy: 0.9675 - loss: 0.1071 - val_accuracy: 0.9753 - val_loss: 0.0856
# Epoch 3/5
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 2s 720us/step - accuracy: 0.9773 - loss: 0.0732 - val_accuracy: 0.9737 - val_loss: 0.0844
# Epoch 4/5
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 3s 910us/step - accuracy: 0.9831 - loss: 0.0543 - val_accuracy: 0.9788 - val_loss: 0.0705
# Epoch 5/5
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 3s 938us/step - accuracy: 0.9862 - loss: 0.0419 - val_accuracy: 0.9808 - val_loss: 0.0745
# Epoch 1/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 2s 864us/step - accuracy: 0.9229 - loss: 0.2697 - val_accuracy: 0.9625 - val_loss: 0.1336
# Epoch 2/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 1s 807us/step - accuracy: 0.9648 - loss: 0.1203 - val_accuracy: 0.9713 - val_loss: 0.0932
# Epoch 3/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 1s 812us/step - accuracy: 0.9749 - loss: 0.0813 - val_accuracy: 0.9778 - val_loss: 0.0814
# Epoch 4/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 1s 795us/step - accuracy: 0.9817 - loss: 0.0609 - val_accuracy: 0.9753 - val_loss: 0.0787
# Epoch 5/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 1s 798us/step - accuracy: 0.9854 - loss: 0.0471 - val_accuracy: 0.9788 - val_loss: 0.0755
# Epoch 1/5
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9090 - loss: 0.3199 - val_accuracy: 0.9645 - val_loss: 0.1350
# Epoch 2/5
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 1s 975us/step - accuracy: 0.9586 - loss: 0.1429 - val_accuracy: 0.9718 - val_loss: 0.1040
# Epoch 3/5
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 1s 986us/step - accuracy: 0.9717 - loss: 0.0966 - val_accuracy: 0.9757 - val_loss: 0.0868
# Epoch 4/5
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 1s 978us/step - accuracy: 0.9785 - loss: 0.0724 - val_accuracy: 0.9763 - val_loss: 0.0797
# Epoch 5/5
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 1s 987us/step - accuracy: 0.9829 - loss: 0.0563 - val_accuracy: 0.9772 - val_loss: 0.0795
# Epoch 1/5
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 3s 735us/step - accuracy: 0.9185 - loss: 0.2813 - val_accuracy: 0.9348 - val_loss: 0.2466
# Epoch 2/5
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 3s 739us/step - accuracy: 0.9420 - loss: 0.2142 - val_accuracy: 0.9472 - val_loss: 0.1890
# Epoch 3/5
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 2s 720us/step - accuracy: 0.9508 - loss: 0.1888 - val_accuracy: 0.9563 - val_loss: 0.1983
# Epoch 4/5
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 2s 727us/step - accuracy: 0.9553 - loss: 0.1769 - val_accuracy: 0.9510 - val_loss: 0.2194
# Epoch 5/5
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 2s 721us/step - accuracy: 0.9568 - loss: 0.1713 - val_accuracy: 0.9623 - val_loss: 0.1713
# Epoch 1/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 2s 867us/step - accuracy: 0.9268 - loss: 0.2466 - val_accuracy: 0.9540 - val_loss: 0.1596
# Epoch 2/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 1s 816us/step - accuracy: 0.9546 - loss: 0.1651 - val_accuracy: 0.9613 - val_loss: 0.1538
# Epoch 3/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 1s 812us/step - accuracy: 0.9609 - loss: 0.1445 - val_accuracy: 0.9567 - val_loss: 0.1755
# Epoch 4/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 1s 808us/step - accuracy: 0.9647 - loss: 0.1327 - val_accuracy: 0.9683 - val_loss: 0.1373
# Epoch 5/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 1s 809us/step - accuracy: 0.9693 - loss: 0.1198 - val_accuracy: 0.9688 - val_loss: 0.1391
# Epoch 1/5
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9311 - loss: 0.2273 - val_accuracy: 0.9663 - val_loss: 0.1171
# Epoch 2/5
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 1s 989us/step - accuracy: 0.9618 - loss: 0.1292 - val_accuracy: 0.9710 - val_loss: 0.1131
# Epoch 3/5
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 1s 972us/step - accuracy: 0.9676 - loss: 0.1103 - val_accuracy: 0.9597 - val_loss: 0.1533
# Epoch 4/5
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 1s 992us/step - accuracy: 0.9726 - loss: 0.0941 - val_accuracy: 0.9695 - val_loss: 0.1390
# Epoch 5/5
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 1s 985us/step - accuracy: 0.9753 - loss: 0.0889 - val_accuracy: 0.9698 - val_loss: 0.1400
# Epoch 1/5
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 3s 742us/step - accuracy: 0.3233 - loss: 1.9742 - val_accuracy: 0.2568 - val_loss: 2.0674
# Epoch 2/5
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 2s 719us/step - accuracy: 0.2747 - loss: 2.0006 - val_accuracy: 0.2860 - val_loss: 1.8786
# Epoch 3/5
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 2s 720us/step - accuracy: 0.2824 - loss: 1.9372 - val_accuracy: 0.2370 - val_loss: 1.9987
# Epoch 4/5
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 2s 731us/step - accuracy: 0.2800 - loss: 1.9748 - val_accuracy: 0.3323 - val_loss: 1.9343
# Epoch 5/5
# 3375/3375 ━━━━━━━━━━━━━━━━━━━━ 2s 715us/step - accuracy: 0.2675 - loss: 1.9503 - val_accuracy: 0.1522 - val_loss: 2.2147
# Epoch 1/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 2s 838us/step - accuracy: 0.5423 - loss: 1.3773 - val_accuracy: 0.4345 - val_loss: 1.6011
# Epoch 2/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 1s 831us/step - accuracy: 0.4724 - loss: 1.4737 - val_accuracy: 0.3683 - val_loss: 1.6921
# Epoch 3/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 1s 811us/step - accuracy: 0.4477 - loss: 1.5301 - val_accuracy: 0.5227 - val_loss: 1.4091
# Epoch 4/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 1s 800us/step - accuracy: 0.4671 - loss: 1.4735 - val_accuracy: 0.4753 - val_loss: 1.5287
# Epoch 5/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 1s 806us/step - accuracy: 0.4344 - loss: 1.5776 - val_accuracy: 0.4332 - val_loss: 1.6239
# Epoch 1/5
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8270 - loss: 0.7608 - val_accuracy: 0.8712 - val_loss: 0.4996
# Epoch 2/5
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 1s 953us/step - accuracy: 0.8353 - loss: 0.6883 - val_accuracy: 0.8282 - val_loss: 0.6221
# Epoch 3/5
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 1s 970us/step - accuracy: 0.7835 - loss: 0.8500 - val_accuracy: 0.8157 - val_loss: 0.6964
# Epoch 4/5
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 1s 965us/step - accuracy: 0.7975 - loss: 0.8041 - val_accuracy: 0.8092 - val_loss: 0.6892
# Epoch 5/5
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 1s 973us/step - accuracy: 0.7146 - loss: 0.9670 - val_accuracy: 0.7753 - val_loss: 0.9404

# %%
best_result = max(results, key=lambda x: x[2])
print(f"Best Result: Learning Rate: {best_result[0]}, Batch Size: {best_result[1]}, Accuracy: {best_result[2]}")
# Out:
# Best Result: Learning Rate: 0.1, Batch Size: 16, Accuracy: 2.268219470977783
