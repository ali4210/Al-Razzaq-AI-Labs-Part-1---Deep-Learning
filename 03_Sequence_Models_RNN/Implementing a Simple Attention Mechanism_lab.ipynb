# %%
import tensorflow as tf

class SimpleAttention(tf.keras.layers.Layer):
    def __init__(self, units):
        super(SimpleAttention, self).__init__()
        self.W_a = tf.keras.layers.Dense(units)
        self.U_a = tf.keras.layers.Dense(units)
        self.V_a = tf.keras.layers.Dense(1)

    def call(self, encoder_states, decoder_hidden):
        score = self.V_a(tf.nn.tanh(self.W_a(encoder_states) + self.U_a(decoder_hidden)))
        attention_weights = tf.nn.softmax(score, axis=1)
        context_vector = attention_weights * encoder_states
        context_vector = tf.reduce_sum(context_vector, axis=1)
        return context_vector, attention_weights

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_dataset, epochs=10, validation_data=val_dataset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#       2 history = model.fit(train_dataset, epochs=10, validation_data=val_dataset)
#
# NameError: name 'model' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_attention(attention, sentence, translation):
    fig = plt.figure(figsize=(10,10))
    ax = fig.add_subplot(1, 1, 1)
    sns.heatmap(attention, cmap='viridis', annot=True, fmt=".2f",
                xticklabels=sentence.split(),
                yticklabels=translation.split())
    plt.xlabel('Input Sequence')
    plt.ylabel('Output Sequence')
    plt.show()

# Example usage
plot_attention(attention_weights.numpy(), input_sentence, output_sentence)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 15
#      12     plt.show()
#      14 # Example usage
# ---> 15 plot_attention(attention_weights.numpy(), input_sentence, output_sentence)
#
# NameError: name 'attention_weights' is not defined
