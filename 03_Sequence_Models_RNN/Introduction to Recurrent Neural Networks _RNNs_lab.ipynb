# %%
# Importing necessary libraries
import numpy as np
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense

# %%
# Define RNN model
model = Sequential()
model.add(SimpleRNN(units=50, activation='relu', input_shape=(timesteps, features)))
model.add(Dense(units=1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Define RNN model
#       2 model = Sequential()
# ----> 3 model.add(SimpleRNN(units=50, activation='relu', input_shape=(timesteps, features)))
#       4 model.add(Dense(units=1))
#
# NameError: name 'timesteps' is not defined

# %%
# Generating a sequence data
X = np.array([[i, i+1, i+2] for i in range(100)])
y = np.array([i+3 for i in range(100)])

# %%
# Compiling the model
model.compile(optimizer='adam', loss='mse')

# Reshape data into compatible format (samples, timesteps, features)
X = X.reshape((X.shape[0], X.shape[1], 1))

# Training the model
model.fit(X, y, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 8
#       5 X = X.reshape((X.shape[0], X.shape[1], 1))
#       7 # Training the model
# ----> 8 model.fit(X, y, epochs=200, verbose=1)
#
# File ~\PycharmProjects\pythonProject3\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\PycharmProjects\pythonProject3\.venv\Lib\site-packages\keras\src\models\sequential.py:172, in Sequential.build(self, input_shape)
#     170     return
#     171 if not self._layers:
# ...

# %%
# Making predictions
y_pred = model.predict(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Making predictions
# ----> 2 y_pred = model.predict(X)
#
# File ~\PycharmProjects\pythonProject3\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\PycharmProjects\pythonProject3\.venv\Lib\site-packages\keras\src\models\sequential.py:172, in Sequential.build(self, input_shape)
#     170     return
#     171 if not self._layers:
# --> 172     raise ValueError(
# ...

# %%
import matplotlib.pyplot as plt

# Visualize the accuracy and predictions
plt.plot(y, label='Actual Sequence')
plt.plot(y_pred, label='Predicted Sequence', linestyle='--')
plt.legend()
plt.title('Sequence Prediction')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 5
#       3 # Visualize the accuracy and predictions
#       4 plt.plot(y, label='Actual Sequence')
# ----> 5 plt.plot(y_pred, label='Predicted Sequence', linestyle='--')
#       6 plt.legend()
#       7 plt.title('Sequence Prediction')
#
# NameError: name 'y_pred' is not defined
